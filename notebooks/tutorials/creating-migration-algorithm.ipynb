# %% [markdown]
# # Creating a Migration Algorithm
#
# This tutorial demonstrates how we can create a simple migration algorithm on EdgeSimPy.
#
# First, let's import the EdgeSimPy modules:

# %%
# Downloading EdgeSimPy binaries from GitHub (the "-q" parameter suppresses Pip's output. You check the full logs by removing it)
# %pip install -q git+https://github.com/EdgeSimPy/EdgeSimPy.git@v1.1.0

# Importing EdgeSimPy components
from edge_sim_py import *

# %% [markdown]
# ## Implementing the Migration Algorithm
#
# Our simple migration algorithm will work according to the well-known Worst-Fit heuristic. In a nutshell, it will provision each service to the edge server with the largest amount of free resources.

# %%
def my_algorithm(parameters):
    # Let's iterate over the list of services using the 'all()' helper method
    print("\n\n")
    for service in Service.all():
        # We don't want to migrate services are are already being migrated
        if not service.being_provisioned:
            # We need to sort edge servers based on amount of free resources they have. To do so, we are going to use Python's
            # "sorted" method (you can learn more about "sorted()" in this link: https://docs.python.org/3/howto/sorting.html). As
            # the capacity of edge servers is modeled in three layers (CPU, memory, and disk), we calculate the geometric mean
            # between these to get the average resource utilization of edge servers. Finally, we set the sorted method "reverse"
            # attribute as "True" as we want to sort edge servers by their free resources in descending order
            edge_servers = sorted(
                EdgeServer.all(),
                key=lambda s: ((s.cpu - s.cpu_demand) * (s.memory - s.memory_demand) * (s.disk - s.disk_demand)) ** (1 / 3),
                reverse=True,
            )
            for edge_server in edge_servers:
                # Checking if the edge server has resources to host the service
                if edge_server.has_capacity_to_host(service=service):
                    # We just need to migrate the service if it's not already in the least occupied edge server
                    if service.server != edge_server:
                        print(f"[STEP {parameters['current_step']}] Migrating {service} From {service.server} to {edge_server}")
                        service.provision(target_server=edge_server)
                        # After start migrating the service we can move on to the next service
                        break

# %% [markdown]
# ## Running the Simulation
#
# Before testing our algorithm, we must tell EdgeSimPy when it must stop the simulation. For example, let's run the simulation for 600 seconds (i.e., 10 minutes).
#
# To do so, we must create a simple function that will be used as the simulation's stopping criterion. Behind the scenes, at the end of each time step, EdgeSimPy will run that function, halting the simulation if it returns `True`.

# %%
def stopping_criterion(model: object):
    # As EdgeSimPy will halt the simulation whenever this function returns True,
    # its output will be a boolean expression that checks if the current time step is 600
    return model.schedule.steps == 600

# %% [markdown]
# Once we have developed our stopping criterion function, we can create an instance of the `Simulation` class passing a couple of arguments, load a dataset, and run the simulation to check how our algorithm goes.

# %%
# Creating a Simulator object
simulator = Simulator(
    tick_duration=1,
    tick_unit="seconds",
    stopping_criterion=stopping_criterion,
    resource_management_algorithm=my_algorithm,
)

# Loading a sample dataset from GitHub
simulator.initialize(input_file="https://raw.githubusercontent.com/EdgeSimPy/edgesimpy-tutorials/master/datasets/sample_dataset1.json")

# Executing the simulation
simulator.run_model()
# Out:
# [STEP 1] Migrating Service_1 From EdgeServer_5 to EdgeServer_1
# [STEP 1] Migrating Service_2 From EdgeServer_5 to EdgeServer_2
# [STEP 1] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 1] Migrating Service_4 From EdgeServer_4 to EdgeServer_6
# [STEP 1] Migrating Service_5 From EdgeServer_4 to EdgeServer_1
# [STEP 1] Migrating Service_6 From EdgeServer_6 to EdgeServer_2
#
#
#
# [STEP 2] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 2] Migrating Service_4 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 3] Migrating Service_1 From EdgeServer_1 to EdgeServer_5
# [STEP 3] Migrating Service_2 From EdgeServer_2 to EdgeServer_5
# [STEP 3] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
#
#
#
# [STEP 4] Migrating Service_1 From EdgeServer_5 to EdgeServer_6
# [STEP 4] Migrating Service_2 From EdgeServer_5 to EdgeServer_2
# [STEP 4] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
#
#
#
# [STEP 5] Migrating Service_2 From EdgeServer_2 to EdgeServer_5
# [STEP 5] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 5] Migrating Service_6 From EdgeServer_2 to EdgeServer_6
#
#
#
# [STEP 6] Migrating Service_1 From EdgeServer_6 to EdgeServer_2
# [STEP 6] Migrating Service_2 From EdgeServer_5 to EdgeServer_2
# [STEP 6] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 6] Migrating Service_6 From EdgeServer_6 to EdgeServer_5
#
#
#
# [STEP 7] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 7] Migrating Service_2 From EdgeServer_2 to EdgeServer_6
# [STEP 7] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 7] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 7] Migrating Service_6 From EdgeServer_5 to EdgeServer_2
#
#
#
# [STEP 8] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 8] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 8] Migrating Service_3 From EdgeServer_5 to EdgeServer_1
# [STEP 8] Migrating Service_5 From EdgeServer_6 to EdgeServer_2
# [STEP 8] Migrating Service_6 From EdgeServer_2 to EdgeServer_6
#
#
#
# [STEP 9] Migrating Service_1 From EdgeServer_2 to EdgeServer_6
# [STEP 9] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 9] Migrating Service_3 From EdgeServer_1 to EdgeServer_5
# [STEP 9] Migrating Service_4 From EdgeServer_1 to EdgeServer_5
# [STEP 9] Migrating Service_5 From EdgeServer_2 to EdgeServer_6
# [STEP 9] Migrating Service_6 From EdgeServer_6 to EdgeServer_2
#
#
#
# [STEP 10] Migrating Service_1 From EdgeServer_6 to EdgeServer_1
# [STEP 10] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 10] Migrating Service_3 From EdgeServer_5 to EdgeServer_2
# [STEP 10] Migrating Service_4 From EdgeServer_5 to EdgeServer_1
# [STEP 10] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 10] Migrating Service_6 From EdgeServer_2 to EdgeServer_6
#
#
#
# [STEP 11] Migrating Service_1 From EdgeServer_1 to EdgeServer_6
# [STEP 11] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 11] Migrating Service_4 From EdgeServer_1 to EdgeServer_5
# [STEP 11] Migrating Service_5 From EdgeServer_1 to EdgeServer_2
# [STEP 11] Migrating Service_6 From EdgeServer_6 to EdgeServer_2
#
#
#
# [STEP 12] Migrating Service_1 From EdgeServer_6 to EdgeServer_1
# [STEP 12] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 12] Migrating Service_4 From EdgeServer_5 to EdgeServer_6
# [STEP 12] Migrating Service_5 From EdgeServer_2 to EdgeServer_1
# [STEP 12] Migrating Service_6 From EdgeServer_2 to EdgeServer_6
#
#
#
# [STEP 13] Migrating Service_1 From EdgeServer_1 to EdgeServer_6
# [STEP 13] Migrating Service_2 From EdgeServer_5 to EdgeServer_2
# [STEP 13] Migrating Service_4 From EdgeServer_6 to EdgeServer_5
# [STEP 13] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 13] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 14] Migrating Service_1 From EdgeServer_6 to EdgeServer_5
# [STEP 14] Migrating Service_2 From EdgeServer_2 to EdgeServer_6
# [STEP 14] Migrating Service_4 From EdgeServer_5 to EdgeServer_1
# [STEP 14] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 14] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 15] Migrating Service_1 From EdgeServer_5 to EdgeServer_6
# [STEP 15] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 15] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 15] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 15] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 16] Migrating Service_1 From EdgeServer_6 to EdgeServer_5
# [STEP 16] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 16] Migrating Service_3 From EdgeServer_2 to EdgeServer_5
# [STEP 16] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 16] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 16] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 17] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 17] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 17] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 17] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 17] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 17] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 18] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 18] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 18] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 18] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 18] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 18] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 19] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 19] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 19] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 19] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 19] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 19] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 20] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 20] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 20] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 20] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 20] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 20] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 21] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 21] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 21] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 21] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 21] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 21] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 22] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 22] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 22] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 22] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 22] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 22] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 23] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 23] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 23] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 23] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 23] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 23] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 24] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 24] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 24] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 24] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 24] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 24] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 25] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 25] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 25] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 25] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 25] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 25] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 26] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 26] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 26] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 26] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 26] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 26] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 27] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 27] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 27] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 27] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 27] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 27] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 28] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 28] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 28] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 28] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 28] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 28] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 29] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 29] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 29] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 29] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 29] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 29] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 30] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 30] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 30] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 30] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 30] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 30] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 31] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 31] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 31] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 31] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 31] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 31] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 32] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 32] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 32] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 32] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 32] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 32] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 33] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 33] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 33] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 33] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 33] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 33] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 34] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 34] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 34] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 34] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 34] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 34] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 35] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 35] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 35] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 35] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 35] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 35] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 36] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 36] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 36] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 36] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 36] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 36] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 37] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 37] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 37] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 37] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 37] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 37] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 38] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 38] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 38] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 38] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 38] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 38] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 39] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 39] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 39] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 39] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 39] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 39] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 40] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 40] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 40] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 40] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 40] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 40] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 41] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 41] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 41] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 41] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 41] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 41] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 42] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 42] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 42] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 42] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 42] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 42] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 43] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 43] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 43] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 43] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 43] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 43] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 44] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 44] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 44] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 44] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 44] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 44] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 45] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 45] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 45] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 45] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 45] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 45] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 46] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 46] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 46] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 46] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 46] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 46] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 47] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 47] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 47] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 47] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 47] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 47] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 48] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 48] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 48] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 48] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 48] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 48] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 49] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 49] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 49] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 49] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 49] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 49] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 50] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 50] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 50] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 50] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 50] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 50] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 51] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 51] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 51] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 51] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 51] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 51] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 52] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 52] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 52] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 52] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 52] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 52] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 53] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 53] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 53] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 53] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 53] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 53] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 54] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 54] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 54] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 54] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 54] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 54] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 55] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 55] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 55] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 55] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 55] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 55] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 56] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 56] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 56] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 56] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 56] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 56] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 57] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 57] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 57] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 57] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 57] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 57] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 58] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 58] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 58] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 58] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 58] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 58] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 59] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 59] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 59] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 59] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 59] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 59] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 60] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 60] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 60] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 60] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 60] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 60] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 61] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 61] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 61] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 61] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 61] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 61] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 62] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 62] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 62] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 62] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 62] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 62] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 63] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 63] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 63] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 63] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 63] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 63] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 64] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 64] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 64] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 64] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 64] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 64] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 65] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 65] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 65] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 65] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 65] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 65] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 66] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 66] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 66] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 66] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 66] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 66] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 67] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 67] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 67] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 67] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 67] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 67] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 68] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 68] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 68] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 68] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 68] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 68] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 69] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 69] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 69] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 69] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 69] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 69] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 70] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 70] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 70] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 70] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 70] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 70] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 71] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 71] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 71] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 71] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 71] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 71] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 72] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 72] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 72] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 72] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 72] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 72] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 73] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 73] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 73] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 73] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 73] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 73] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 74] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 74] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 74] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 74] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 74] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 74] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 75] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 75] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 75] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 75] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 75] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 75] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 76] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 76] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 76] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 76] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 76] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 76] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 77] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 77] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 77] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 77] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 77] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 77] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 78] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 78] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 78] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 78] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 78] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 78] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 79] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 79] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 79] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 79] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 79] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 79] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 80] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 80] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 80] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 80] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 80] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 80] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 81] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 81] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 81] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 81] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 81] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 81] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 82] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 82] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 82] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 82] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 82] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 82] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 83] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 83] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 83] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 83] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 83] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 83] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 84] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 84] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 84] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 84] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 84] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 84] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 85] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 85] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 85] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 85] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 85] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 85] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 86] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 86] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 86] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 86] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 86] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 86] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 87] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 87] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 87] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 87] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 87] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 87] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 88] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 88] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 88] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 88] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 88] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 88] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 89] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 89] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 89] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 89] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 89] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 89] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 90] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 90] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 90] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 90] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 90] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 90] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 91] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 91] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 91] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 91] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 91] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 91] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 92] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 92] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 92] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 92] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 92] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 92] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 93] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 93] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 93] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 93] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 93] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 93] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 94] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 94] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 94] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 94] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 94] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 94] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 95] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 95] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 95] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 95] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 95] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 95] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 96] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 96] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 96] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 96] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 96] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 96] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 97] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 97] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 97] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 97] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 97] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 97] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 98] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 98] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 98] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 98] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 98] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 98] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 99] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 99] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 99] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 99] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 99] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 99] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 100] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 100] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 100] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 100] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 100] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 100] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 101] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 101] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 101] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 101] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 101] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 101] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 102] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 102] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 102] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 102] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 102] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 102] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 103] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 103] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 103] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 103] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 103] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 103] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 104] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 104] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 104] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 104] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 104] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 104] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 105] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 105] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 105] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 105] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 105] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 105] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 106] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 106] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 106] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 106] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 106] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 106] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 107] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 107] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 107] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 107] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 107] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 107] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 108] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 108] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 108] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 108] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 108] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 108] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 109] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 109] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 109] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 109] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 109] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 109] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 110] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 110] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 110] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 110] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 110] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 110] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 111] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 111] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 111] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 111] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 111] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 111] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 112] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 112] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 112] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 112] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 112] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 112] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 113] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 113] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 113] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 113] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 113] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 113] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 114] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 114] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 114] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 114] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 114] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 114] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 115] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 115] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 115] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 115] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 115] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 115] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 116] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 116] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 116] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 116] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 116] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 116] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 117] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 117] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 117] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 117] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 117] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 117] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 118] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 118] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 118] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 118] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 118] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 118] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 119] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 119] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 119] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 119] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 119] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 119] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 120] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 120] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 120] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 120] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 120] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 120] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 121] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 121] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 121] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 121] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 121] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 121] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 122] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 122] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 122] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 122] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 122] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 122] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 123] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 123] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 123] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 123] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 123] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 123] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 124] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 124] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 124] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 124] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 124] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 124] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 125] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 125] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 125] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 125] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 125] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 125] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 126] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 126] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 126] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 126] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 126] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 126] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 127] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 127] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 127] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 127] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 127] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 127] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 128] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# ...
# [STEP 560] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 560] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 560] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 560] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 561] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 561] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 561] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 561] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 561] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 561] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 562] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 562] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 562] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 562] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 562] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 562] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 563] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 563] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 563] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 563] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 563] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 563] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 564] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 564] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 564] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 564] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 564] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 564] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 565] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 565] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 565] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 565] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 565] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 565] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 566] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 566] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 566] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 566] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 566] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 566] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 567] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 567] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 567] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 567] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 567] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 567] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 568] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 568] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 568] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 568] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 568] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 568] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 569] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 569] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 569] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 569] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 569] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 569] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 570] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 570] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 570] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 570] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 570] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 570] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 571] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 571] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 571] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 571] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 571] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 571] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 572] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 572] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 572] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 572] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 572] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 572] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 573] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 573] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 573] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 573] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 573] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 573] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 574] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 574] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 574] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 574] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 574] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 574] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 575] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 575] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 575] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 575] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 575] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 575] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 576] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 576] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 576] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 576] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 576] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 576] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 577] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 577] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 577] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 577] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 577] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 577] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 578] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 578] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 578] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 578] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 578] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 578] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 579] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 579] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 579] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 579] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 579] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 579] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 580] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 580] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 580] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 580] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 580] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 580] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 581] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 581] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 581] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 581] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 581] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 581] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 582] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 582] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 582] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 582] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 582] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 582] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 583] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 583] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 583] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 583] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 583] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 583] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 584] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 584] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 584] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 584] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 584] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 584] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 585] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 585] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 585] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 585] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 585] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 585] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 586] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 586] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 586] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 586] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 586] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 586] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 587] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 587] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 587] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 587] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 587] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 587] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 588] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 588] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 588] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 588] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 588] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 588] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 589] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 589] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 589] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 589] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 589] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 589] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 590] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 590] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 590] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 590] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 590] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 590] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 591] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 591] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 591] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 591] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 591] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 591] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 592] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 592] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 592] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 592] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 592] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 592] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 593] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 593] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 593] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 593] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 593] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 593] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 594] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 594] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 594] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 594] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 594] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 594] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 595] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 595] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 595] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 595] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 595] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 595] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 596] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 596] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 596] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 596] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 596] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 596] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 597] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 597] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 597] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 597] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 597] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 597] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 598] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 598] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 598] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 598] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 598] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 598] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
#
#
#
# [STEP 599] Migrating Service_1 From EdgeServer_5 to EdgeServer_2
# [STEP 599] Migrating Service_2 From EdgeServer_6 to EdgeServer_5
# [STEP 599] Migrating Service_3 From EdgeServer_5 to EdgeServer_6
# [STEP 599] Migrating Service_4 From EdgeServer_1 to EdgeServer_2
# [STEP 599] Migrating Service_5 From EdgeServer_1 to EdgeServer_6
# [STEP 599] Migrating Service_6 From EdgeServer_6 to EdgeServer_1
#
#
#
# [STEP 600] Migrating Service_1 From EdgeServer_2 to EdgeServer_5
# [STEP 600] Migrating Service_2 From EdgeServer_5 to EdgeServer_6
# [STEP 600] Migrating Service_3 From EdgeServer_6 to EdgeServer_5
# [STEP 600] Migrating Service_4 From EdgeServer_2 to EdgeServer_1
# [STEP 600] Migrating Service_5 From EdgeServer_6 to EdgeServer_1
# [STEP 600] Migrating Service_6 From EdgeServer_1 to EdgeServer_6
